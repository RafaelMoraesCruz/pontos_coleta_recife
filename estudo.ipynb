# %% [markdown]
# ## Estudo dos pontos de coleta seletiva e resíduos na cidade do Recife

# %% [markdown]
# Importando bibliotecas...

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# DADOS COLETADOS DE: http://dados.recife.pe.gov.br/pt_BR/dataset/pontos-de-coleta-seletiva
# Informações sobre os dados

# %%
resumo = pd.read_html('http://dados.recife.pe.gov.br/pt_BR/dataset/pontos-de-coleta-seletiva')
resumo[0]
# Out:
#                        Campo  \
# 0                      Fonte
# 1                      Autor
# 2                 Mantenedor
# 3                     Versão
# 4         Última Atualização
# 5                     Criado
# 6                  Categoria
# 7  Frequência de atualização
#
#                                                Valor
# 0                        secretaria de meio ambiente
# 1                                             EMPREL
# 2                                             EMPREL
# 3                                                1.0
# 4                29 de Dezembro de 2022, 09:15 (BRT)
# 5                     9 de Maio de 2018, 17:56 (BRT)
# 6  http://vocab.e.gov.br/id/governo#preservacao-c...
# 7                                              Anual

# %% [markdown]
# Visão inicial da planilha

# %%
df = pd.read_csv("http://dados.recife.pe.gov.br/dataset/10a009f2-f9bb-457b-8f78-d8f0dc3ced37/resource/ef521704-6960-4ef1-8f98-a60db4a0d79b/download/pontos_coleta.csv",sep=';')
df
# Out:
#                            tiporesiduo                  bairro  \
# 0                Materiais Recicláveis                São José
# 1                Materiais Recicláveis             Dois Unidos
# 2                Materiais Recicláveis                   Torre
# 3                Materiais Recicláveis                São José
# 4                Materiais Recicláveis               Guabiraba
# ..                                 ...                     ...
# 183  metal,isopor,papel,plastico,vidro  Dois Unidos/Passarinho
# 184                               Pneu                Madalena
# 185                               Pneu              Espinheiro
# 186                               Pneu                São José
# 187                            Lampada             Imbiribeira
#
#                                 endereco                   complemento  \
# 0                            Avenida Sul                           s/n
# 1                    Av. Chagas Ferreira                           601
# 2           Rua Eliezer Olímpio de Moura                           100
# 3                     Travessa do Gusmão                           178
# 4            Av. Padre Mosca de Carvalho                           s/n
# ..                                   ...                           ...
# 183             Av. Chagas Ferreira, 601  Cooperativa Resgatando Vidas
# 184          Av. Abdias de Carvalho, 341                 Pneus Pirelle
# 185                      Av. Norte, 2261             Bridgestone Pneus
# 186              Rua Lourenço de Sá, 165                    Pneu Verde
# 187  Rua Francisco Correa de Moraes, 100      Carrefour RBV Boa Viagem
#
#       observacao  latitude  longitude
# 0    Cooperativa -8.075631 -34.891624
# 1    Cooperativa -8.005045 -34.912247
# 2    Cooperativa -8.044426 -34.912990
# 3    Cooperativa -8.071821 -34.886728
# 4    Cooperativa -7.964258 -34.924600
# ..           ...       ...        ...
# 183  Cooperativa -8.005097 -34.914497
# 184          NaN -8.061416 -34.908718
# 185          NaN -8.039216 -34.893334
# 186          NaN -8.074329 -34.898021
# 187          NaN -8.124149 -34.913300
#
# [188 rows x 7 columns]

# %% [markdown]
# Tipos de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   tiporesiduo  188 non-null    object
#  1   bairro       133 non-null    object
#  2   endereco     188 non-null    object
#  3   complemento  97 non-null     object
#  4   observacao   176 non-null    object
#  5   latitude     188 non-null    float64
#  6   longitude    188 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 10.4+ KB

# %%
# Create a map object and center it to the avarage coordinates to m
m = folium.Map(width=1500,height=1000,location=df[["latitude", "longitude"]].mean().to_list(), zoom_start=12)
# if the points are too close to each other, cluster them, create a cluster overlay with MarkerCluster, add to m
marker_cluster = MarkerCluster().add_to(m)
# draw the markers and assign popup and hover texts
# add the markers the the cluster layers so that they are automatically clustered
for i,r in df.iterrows():
    location = (r["latitude"], r["longitude"])
    folium.Marker(location=location,
                      popup = r['tiporesiduo'],
                      tooltip=r['endereco'])\
    .add_to(marker_cluster)
# display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_610094364716ebb330df8aabd505bb35 {
#                     position: relative;
#                     width: 1500.0px;
#                     height: 1000.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_610094364716ebb330df8aabd505bb35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_610094364716ebb330df8aabd505bb35 = L.map(
#                 &quot;map_610094364716ebb330df8aabd505bb35&quot;,
#                 {
#                     center: [-8.064126734170213, -34.91210371824468],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4958e065fd53c120fea1fee2e322b37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_610094364716ebb330df8aabd505bb35);
#
#
#             var marker_cluster_7f725ac5cca7783456b602da9e8a9744 = L.markerClusterGroup(
#                 {}
#             );
#             map_610094364716ebb330df8aabd505bb35.addLayer(marker_cluster_7f725ac5cca7783456b602da9e8a9744);
#
#
#             var marker_bf0bdea6d745f2e4d7140ed9097dff6f = L.marker(
#                 [-8.075631, -34.891624],
#                 {}
#             ).addTo(marker_cluster_7f725ac5cca7783456b602da9e8a9744);
#
#
#         var popup_7de01e99ffe6b0a0ecd5899b33ada95f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1613ecf0ecb4f4a52af63c9cef79bbd8 = $(`&lt;div id=&quot;html_1613ecf0ecb4f4a52af63c9cef79bbd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Materiais Recicláveis&lt;/div&gt;`)[0];
#                 popup_7de01e99ffe6b0a0ecd5899b33ada95f.setContent(html_1613ecf0ecb4f4a52af63c9cef79bbd8);
#
#
#
#         marker_bf0bdea6d745f2e4d7140ed9097dff6f.bindPopup(popup_7de01e99ffe6b0a0ecd5899b33ada95f)
#         ;
#
#
#
#
#             marker_bf0bdea6d745f2e4d7140ed9097dff6f.bindTooltip(
#                 `&lt;div&gt;
#                      Avenida Sul
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f47db9b26bf5e4f3ad7d41e09103e51a = L.marker(
#                 [-8.005045, -34.912247],
#                 {}
#             ).addTo(marker_cluster_7f725ac5cca7783456b602da9e8a9744);
#
#
#         var popup_a4b89b9e6e085e90f7f985024203bb09 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dce59952112804669f761cd1c7cbcfa4 = $(`&lt;div id=&quot;html_dce59952112804669f761cd1c7cbcfa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Materiais Recicláveis&lt;/div&gt;`)[0];
#                 popup_a4b89b9e6e085e90f7f985024203bb09.setContent(html_dce59952112804669f761cd1c7cbcfa4);
#
#
#
#         marker_f47db9b26bf5e4f3ad7d41e09103e51a.bindPopup(popup_a4b89b9e6e085e90f7f985024203bb09)
#         ;
#
#
#
#
#             marker_f47db9b26bf5e4f3ad7d41e09103e51a.bindTooltip(
#                 `&lt;div&gt;
#                      Av. Chagas Ferreira
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5d29c56a55f738699e3c751634862cc8 = L.marker(
#                 [-8.044426, -34.91299],
#                 {}
#             ).addTo(marker_cluster_7f725ac5cca7783456b602da9e8a9744);
#
#
#         var popup_7ec59da6a739ae5df4f51c07e1b6f0d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4f28eb25e6ebf198b9b7b70ec26639ad = $(`&lt;div id=&quot;html_4f28eb25e6ebf198b9b7b70ec26639ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Materiais Recicláveis&lt;/div&gt;`)[0];
#                 popup_7ec59da6a739ae5df4f51c07e1b6f0d7.setContent(html_4f28eb25e6ebf198b9b7b70ec26639ad);
#
#
#
#         marker_5d29c56a55f738699e3c751634862cc8.bindPopup(popup_7ec59da6a739ae5df4f51c07e1b6f0d7)
#         ;
#
#
#
#
#             marker_5d29c56a55f738699e3c751634862cc8.bindTooltip(
#                 `&lt;div&gt;
#                      Rua Eliezer Olímpio de Moura
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ca311ed4386c9b2fb220241b665e0402 = L.marker(
#                 [-8.071821, -34.886728],
#                 {}
#             ).addTo(marker_cluster_7f725ac5cca7783456b602da9e8a9744);
#
#
#         v
